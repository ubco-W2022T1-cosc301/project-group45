# %% [markdown]
# # Mukhtar Abdsalami

# %% [markdown]
# ## Research question/interests
#
# What is the correlation between the number of children or dependants and the amount of charges? Furthermore, how are these trends affected by factors such as sex and/or region?
#
# My interest lies in if the number of children increases or decreases cost and the possible reasons for these trends. Factors such as sex and/or region might also affect the variability in how number of children affect costs so I want to analyze them further. In a country like the United States with private healthcare some individuals with children might be more or less willing to seek medical attention if they also have dependants they have to pay for. This willingless to seek help and in turn the amount of charges I believe could also be affected by the local laws of regions, access to medicine in these regions and the sex of the individual.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
med_data = pd.read_csv("https://gist.githubusercontent.com/meperezcuello/82a9f1c1c473d6585e750ad2e3c05a41/raw/d42d226d0dd64e7f5395a0eec1b9190a10edbc03/Medical_Cost.csv")

med_data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# # Milestone 3
#
# ## Task 1: Exploratory Data Analysis

# %% [markdown]
# I will start with some simple exploration on the trends, shape and general details of the data

# %%
med_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
med_data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
med_data.shape
# Out:
# (1338, 7)

# %%
med_data.describe().T
# Out:
#            count          mean           std        min         25%       50%  \
# age       1338.0     39.207025     14.049960    18.0000    27.00000    39.000
# bmi       1338.0     30.663397      6.098187    15.9600    26.29625    30.400
# children  1338.0      1.094918      1.205493     0.0000     0.00000     1.000
# charges   1338.0  13270.422265  12110.011237  1121.8739  4740.28715  9382.033
#
#                    75%          max
# age          51.000000     64.00000
# bmi          34.693750     53.13000
# children      2.000000      5.00000
# charges   16639.912515  63770.42801

# %% [markdown]
# The only numerical stats that are valuable to me are the children and charges row. We can see that on average the individuals surveyed have 1 child with a max of 5 children. Furthermore we see what the max, min and different percentiles are which we can use to seperate charges into categories of expensive to relatively cheap.

# %%
med_data.nunique()
# Out:
# age           47
# sex            2
# bmi          548
# children       6
# smoker         2
# region         4
# charges     1337
# dtype: int64

# %% [markdown]
# There are **4** regions, **2** sexes and **6** different number of children ranging from 0 to 5 which we know from the previous visualization. I will likely have to manipulate and combine these factors into seperate subset dataframes of sex/region and sex/# of children to see the resulting effect on charges

# %%
plt1 = med_data.plot(kind='scatter', x='charges', y='children', figsize=(18,12))

plt1.set_title("Charges by number of Children")

plt.show()

# %% [markdown]
# As the number of children increases there is an inverse relationship in the cost. I would have predicted an increase in charges instead which could mean other factors such as sex and region are involved.

# %%
med_data['children'].value_counts()
# Out:
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %% [markdown]
# There aren't as many samples for less children so I need to take this into account when answering my research question

# %%
plt2 = sns.relplot(x= 'charges', y= 'region', hue = 'children', data = med_data, height= 4, aspect= 6)

# %% [markdown]
# Each region has different areas of concentration for charges which we can see through the darker plots. This could indicate that the laws and or access to medical attention in different regions could be affecting how charges change based on your number of children.

# %%
sns.relplot(x= 'charges', y= 'sex', hue = 'children', data = med_data, height= 2, aspect= 10)

# %% [markdown]
# Based on this plot I cannot extract a direct correlation to sex and how they change charges for individuals with children so there might not be a connection or I might need to combine sex with region. I will explore this further in my data analysis.

# %%
sns.displot(med_data, x="charges", col="region", row="sex")

# %% [markdown]
# From this plot I can see that the regions have some variances in charges depending on sex and region. In order to better understand how this relationship is affected by status as a parent or guardian I will create subplots that specify status.

# %%
sns.pairplot(med_data, corner=True)

# %% [markdown]
# The bmi has no significant correlation to how charges change for a parent/guardian as it would not affect their decision making process of seeking expensive medical attention. We can clearly see that there is a trend in how age is affecting charges as you get older but age is not connected to my research question. I will be removing this column in future tasks.

# %% [markdown]
# ## Task 2: Data Analysis Pipeline

# %% [markdown]
# 1. Load Data

# %%
med_data = pd.read_csv("../data/raw/Medical_cost.csv")

# %% [markdown]
# 2. Clean Data
#
# - I will be removing the smoker, bmi and age columns since although they provide important information for how charges increase or decrease due to their effects on health they are not relevant to my research question. I want to know how the status of being a guardian affects charges and how the trend is further influenced by region and sex.

# %%
muk_med_data = med_data.drop(['age','smoker', 'bmi'], axis=1)
muk_med_data.head()
# Out:
#       sex  children     region      charges
# 0  female         0  southwest  16884.92400
# 1    male         1  southeast   1725.55230
# 2    male         3  southeast   4449.46200
# 3    male         0  northwest  21984.47061
# 4    male         0  northwest   3866.85520

# %% [markdown]
# 3. Process Data
#
# - I will also add a column for the status of each individual as a parent or guardian so when I start my data analysis we can see if there is a more noticable change in charges once you have a child at all.
# - I'll also add a column that combines sex/region for easier data processing when answering my research question

# %%
muk_med_data["parent"]= muk_med_data["children"] > 0

muk_med_data
# Out:
#          sex  children     region      charges  parent
# 0     female         0  southwest  16884.92400   False
# 1       male         1  southeast   1725.55230    True
# 2       male         3  southeast   4449.46200    True
# 3       male         0  northwest  21984.47061   False
# 4       male         0  northwest   3866.85520   False
# ...      ...       ...        ...          ...     ...
# 1333    male         3  northwest  10600.54830    True
# 1334  female         0  northeast   2205.98080   False
# 1335  female         0  southeast   1629.83350   False
# 1336  female         0  southwest   2007.94500   False
# 1337  female         0  northwest  29141.36030   False
#
# [1338 rows x 5 columns]

# %%
muk_med_data["sex_region"]= muk_med_data['sex'].astype(str) + "_" + muk_med_data['region'].astype(str)

muk_med_data
# Out:
#          sex  children     region      charges  parent        sex_region
# 0     female         0  southwest  16884.92400   False  female_southwest
# 1       male         1  southeast   1725.55230    True    male_southeast
# 2       male         3  southeast   4449.46200    True    male_southeast
# 3       male         0  northwest  21984.47061   False    male_northwest
# 4       male         0  northwest   3866.85520   False    male_northwest
# ...      ...       ...        ...          ...     ...               ...
# 1333    male         3  northwest  10600.54830    True    male_northwest
# 1334  female         0  northeast   2205.98080   False  female_northeast
# 1335  female         0  southeast   1629.83350   False  female_southeast
# 1336  female         0  southwest   2007.94500   False  female_southwest
# 1337  female         0  northwest  29141.36030   False  female_northwest
#
# [1338 rows x 6 columns]

# %% [markdown]
# ## Task 3: Method Chaining

# %%
import project_functions2 as pf2

# %%
df = pf2.load_and_process("../data/raw/Medical_Cost.csv")

# %%
df
# Out:
#          sex  children     region      charges        sex_region  parent
# 0     female         0  southwest  16884.92400  female_southwest   False
# 1       male         1  southeast   1725.55230    male_southeast    True
# 2       male         3  southeast   4449.46200    male_southeast    True
# 3       male         0  northwest  21984.47061    male_northwest   False
# 4       male         0  northwest   3866.85520    male_northwest   False
# ...      ...       ...        ...          ...               ...     ...
# 1333    male         3  northwest  10600.54830    male_northwest    True
# 1334  female         0  northeast   2205.98080  female_northeast   False
# 1335  female         0  southeast   1629.83350  female_southeast   False
# 1336  female         0  southwest   2007.94500  female_southwest   False
# 1337  female         0  northwest  29141.36030  female_northwest   False
#
# [1338 rows x 6 columns]

# %% [markdown]
# ## Task 4: Data Analysis

# %% [markdown]
# - To answer my research question we will reorganize the the datasets to output tables that essentially answer our question.
# - These tables will include show us how sex and region affect charges and then we will include parental status to bring everything together.
# - In addition to tables I will add some graphs that draw together our observations

# %%
df_sr = df.groupby(['sex_region'])['charges'].mean().sort_values(ascending = False).reset_index()

df_sr
# Out:
#          sex_region       charges
# 0    male_southeast  15879.617173
# 1    male_northeast  13854.005374
# 2  female_southeast  13499.669243
# 3    male_southwest  13412.883576
# 4  female_northeast  12953.203151
# 5  female_northwest  12479.870397
# 6    male_northwest  12354.119575
# 7  female_southwest  11274.411264

# %%
plt.figure(figsize=(10,8))
sns.barplot(x = 'charges', y= 'sex_region', data = df_sr)
plt.xlabel("Charges")
plt.ylabel("Individuals Sex & Region of Origin")
plt.title("Ranking Individuals Charges by Sex & Region")

plt.show()

# %% [markdown]
# - This table shows the average charges for male and females seperated by each 4 regions southeast, northeast, southwest and northwest
# - I am using average charges as since there is a different number of charges available for each region if we only consider the total then the outputed table will not have an impactful meaning
# - Our Analysis shows that regardless of being seperated by region, on average males have higher medical costs than females. There is an exception for the Northwest region which has similar charges across sexes.

# %%
df_srp = df.groupby(["parent", "sex_region"])["charges"].mean().sort_values(ascending = False).reset_index()

df_srp
# Out:
#     parent        sex_region       charges
# 0     True    male_southeast  17445.474991
# 1     True  female_northeast  15512.342692
# 2    False  female_southeast  14862.013008
# 3     True    male_northeast  14249.773557
# 4     True    male_northwest  13863.713659
# 5    False    male_southeast  13791.806750
# 6    False    male_southwest  13727.264465
# 7    False    male_northeast  13389.637372
# 8     True    male_southwest  13182.114626
# 9    False  female_northwest  12583.872074
# 10    True  female_southeast  12453.829585
# 11    True  female_northwest  12398.477779
# 12    True  female_southwest  12108.840696
# 13   False  female_southwest  10149.745507
# 14   False    male_northwest   9812.969532
# 15   False  female_northeast   9789.822330

# %%
df_plot = pd.read_csv("../data/processed/sex_region_parent.csv")

df_plot = df_plot.groupby(['sex_region_parent'])['charges'].mean().sort_values(ascending = False).reset_index()

plt.figure(figsize=(10,15))
sns.barplot(x = 'charges', y= 'sex_region_parent', data = df_plot)
plt.xlabel("Charges")
plt.ylabel("Individuals by Sex, Region of Origin and Parental Status")
plt.title("Ranking Parents/Non-Parents Medical Charges by Sex & Region")

plt.show()

# %% [markdown]
# - Once we include the status of these individuals as parents to our analysis we notice more nuanced trends.
# - Females have relatively similar costs regardless of status as a parent with an exception to the Northeast which has a significant jump in cost. We will consider the excpetion to be an anomaly.
# - Males on the other hand have similar costs in the northeast and south west regions regardless of parental status but male parents have significant jumps in charges in the northwest and southeast regions.

# %%
plt.figure(figsize=(8,5))
    
sns.violinplot(x = "children", y = "charges", data = df)
plt.title('Variation of Costs by Number of Children')
plt.ylabel('Costs')
plt.xlabel('# of Children of Individuals')

plt.show()

# %% [markdown]
# - This violin plot shows us that despite the assumption that more children would increase the number of charges we actually see that people with 4 children actually have lower and less flunctuation in their charges as oppesed to peopel with 3 children or less. Looking at people with 5 children this observation becomes even more apparant as there is little to no fluctuation in charges and those costs that are recorded for 5 children are lower than average.

# %%
df_final = pd.read_csv("../data/processed/sex_region_parent.csv")

plt.figure(figsize=(15,8))
plt.ylabel('Sex & Region')
plt.xlabel('Charges')
plt.title('Box plot of Charges for Individuals by Sex, Region & Parental Status', fontsize=16)
sns.stripplot(data=df_final, y='sex_region_parent', x='charges', color= 'black', size=2,)
sns.boxplot(data=df_final, y='sex_region_parent', x='charges')

plt.show()

# %% [markdown]
# ## Conclusion
# Overall, the data we are provided shows us that contrary to my previous assumptions parental status does not have a significant or absolute impact on the number of medical cost charges for an Individual in the United States. When looking at how charges are affected by the number of children each individual cares for, we found no pattern to assert an increase due to more children, so we changed the data to simply assess parents and non-parents. By better defining our scope I was able to then include the factors of sex and region to find out the overall correlation of these 3 factors to my research question.
#
# Using data frame manipulation, I created bar plots that show the average medical costs of all 16 subgroups to draw my conclusion. Using the above bar plots and combined box and spring plot, I could conclude the following. Male medical costs on average tend to be higher than female medical costs regardless of whether an individual is a parent or not. Furthermore, in half of the regions (northwest & southeast), we see a significant increase in costs for males with children versus males that don't have children. This draws me to conclude that sex and region can indeed have an influence on medical charges for parents but only in very nuanced cases.

# %% [markdown]
# # Milestone 4
#
# ## Task 1

# %%
df_m4 = pf2.load_and_process("../data/raw/Medical_Cost.csv")

df_m4["sex_region_parent"] = df_m4['sex_region'].astype(str) + "_" + df_m4['parent'].astype(str)

df_m4
# Out:
#          sex  children     region      charges        sex_region  parent  \
# 0     female         0  southwest  16884.92400  female_southwest   False
# 1       male         1  southeast   1725.55230    male_southeast    True
# 2       male         3  southeast   4449.46200    male_southeast    True
# 3       male         0  northwest  21984.47061    male_northwest   False
# 4       male         0  northwest   3866.85520    male_northwest   False
# ...      ...       ...        ...          ...               ...     ...
# 1333    male         3  northwest  10600.54830    male_northwest    True
# 1334  female         0  northeast   2205.98080  female_northeast   False
# 1335  female         0  southeast   1629.83350  female_southeast   False
# 1336  female         0  southwest   2007.94500  female_southwest   False
# 1337  female         0  northwest  29141.36030  female_northwest   False
#
#            sex_region_parent
# 0     female_southwest_False
# 1        male_southeast_True
# ...

# %%
df_m4.to_csv("../data/processed/sex_region_parent.csv", index= False)
